# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
img=mpimg.imread('D:\Anika Gupta\IMPORTANT STUFF\IAMNEO\Coding\Stats and graphical\Matplotlib\Part 7\Screenshot 2024-02-12 182732.png')

# %%
plt.imshow(img)
plt.show()

# %%
import cv2

# %%
imgcv2=cv2.imread('D:\Anika Gupta\IMPORTANT STUFF\IAMNEO\Coding\Stats and graphical\Matplotlib\Part 7\Screenshot 2024-02-12 182732.png')

# %%
plt.imshow(imgcv2)
plt.show()

# %%
imgcv2=cv2.cvtColor(imgcv2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgcv2)
plt.show()

# %%
plt.imshow(img, aspect=1.5)
plt.show()

# %%
img1=mpimg.imread('D:\Anika Gupta\IMPORTANT STUFF\IAMNEO\Coding\Stats and graphical\Matplotlib\Part 7\Screenshot 2024-02-12 182732.png')
img2=mpimg.imread('D:\Anika Gupta\IMPORTANT STUFF\IAMNEO\Coding\Stats and graphical\Matplotlib\Part 7\Screenshot 2024-02-01 210519.png')
img3=mpimg.imread('D:\Anika Gupta\IMPORTANT STUFF\IAMNEO\Coding\Stats and graphical\Matplotlib\Part 7\Screenshot 2024-02-01 210248.png')

# %%
plt.figure() 
plt.subplot(2,2,1)
plt.imshow(img1)

plt.subplot(2,2,2,)
plt.imshow(img2)

plt.subplot(2,2,3)
plt.imshow(img3)

plt.show()

# %%
plt.imshow(img, aspect=1.5)
plt.colorbar()
plt.show()

# %%
plt.imshow(img, cmap='gray')
plt.colorbar()
plt.show()
